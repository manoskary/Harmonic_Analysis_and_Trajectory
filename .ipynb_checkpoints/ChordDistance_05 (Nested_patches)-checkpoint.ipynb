# %% [markdown]
# ## Reading the midi File and finding the chords

# %%
from Tonnetz_Select import *

# %%
chordListConnectNoDoubles, Tonnetz = fromMidiToPCS('Midi_files\midi_export.mid')
# Out:
# 17

# %%
from TrajectoryCalculationsWithClass import *
from ChangeTonnetzSpace import *
from PCSets2Midi import *

# %%
asdf = TrajectoryLookBefore(chordListConnectNoDoubles, Tonnetz)

# %%
PC2Midi(trajectoryRot(asdf, 180), 'Midi_files')
# Out:
# What is the name of the file: midi_export_Rot180
# Please wait while process ...

# %% [markdown]
# ## Trajectory Calculations

# %% [markdown]
# ### Simple Trajectory : two versions

# %%
from TrajectoryCalculations import *

# %%
TrajectoryPoints = Trajectory(chordListConnectNoDoubles, Tonnetz)
TrajectoryPointsLookBefore = TrajectoryLookBefore(chordListConnectNoDoubles, Tonnetz)

# %% [markdown]
# ### 3-seq Trajectory By Looking Ahead and Looking Before

# %%
from TrajectoryCalculationsWtFuture import *

# %%
TrajectoryPoints = NewTrajectory(chordListConnectNoDoubles, Tonnetz)
# TrajectoryPointsLookBefore = NewTrajectoryLookBefore(chordListConnectNoDoubles, Tonnetz)

# %% [markdown]
# ### Let's find the edges

# %%
import itertools as itt
def TrajectoryNoteEdges(TrajectoryPoints, Tonnetz):
    TotalEdges = []
    dist = [-1, 0, 1]
    for dicts in TrajectoryPoints:
        chordEdges = []
        l = list(itt.product(dicts.values(), dicts.values()))
        for couple in l:
            (x1, y1), (x2, y2) = couple
            if (x1 - x2) in dist  and (y1 - y2) in dist:
                if not (((x1 - x2) == 1 and (y1 - y2) == -1) or ((x1 - x2) == -1 and (y1 - y2) == 1)) :
                    chordEdges.append(couple)
        TotalEdges.append(chordEdges)
    return TotalEdges

# %%
TrajectoryV1Edges = TrajectoryNoteEdges(TrajectoryPoints, Tonnetz)
# TrajectoryV2Edges = TrajectoryNoteEdges(TrajectoryPointsLookBefore, Tonnetz)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-3ddee259754b> in <module>
# ----> 1 TrajectoryV1Edges = TrajectoryNoteEdges(TrajectoryPoints, Tonnetz)
#       2 # TrajectoryV2Edges = TrajectoryNoteEdges(TrajectoryPointsLookBefore, Tonnetz)
#
# <ipython-input-12-1d1feb855b9a> in TrajectoryNoteEdges(TrajectoryPoints, Tonnetz)
#       3     TotalEdges = []
#       4     dist = [-1, 0, 1]
# ----> 5     for dicts in TrajectoryPoints:
#       6         chordEdges = []
#       7         l = list(itt.product(dicts.values(), dicts.values()))
#
# TypeError: 'TrajectoryClass' object is not iterable

# %% [markdown]
# ### Let's plot that!

# %% [markdown]
# First just Points

# %%
# %matplotlib notebook

import numpy as np
import pylab as plt
from matplotlib import collections  as mc

fig, ax = plt.subplots()
    
for el in TrajectoryV1Edges:
    line = []
    line = mc.LineCollection(el, linewidths=0.3)
    ax.add_collection(line)
    ax.autoscale()
    ax.margins(0.1)

plt.grid()
plt.axis('equal')


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()


axeX = []
axeY = []

axeX2 = []
axeY2 = []

for dicts in TrajectoryPointsLookBefore:
    for el in dicts:
        x, y = dicts[el]
        axeX2.append(x)
        axeY2.append(y)
    
for dicts in TrajectoryPoints:
    for el in dicts:
        x, y = dicts[el]
        axeX.append(x)
        axeY.append(y)       

        
        
ax.scatter(axeX2, axeY2, c='tab:orange', s=20, label='Trajectory Look Before', alpha=0.6, edgecolors='none')
ax.scatter(axeX, axeY, c='tab:blue', s=20, label='Trajectory', alpha=0.6, edgecolors='none')

ax.legend()
plt.grid()
plt.axis('equal')


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Lets Find all the Edges by building a product on all points

# %%
def TrajectoryAllEdges(TrajectoryPoints):
    TotalEdges = []
    dist = [-1, 0, 1]
    allPoints = []
    for dicts in TrajectoryPoints :
        allPoints = allPoints + list(dicts.values())
    PointsNoDoubles = list(set(allPoints))
    productPoints = itt.product(PointsNoDoubles, PointsNoDoubles)
    for couple in productPoints:
        (x1, y1), (x2, y2) = couple
        if (x1 - x2) in dist  and (y1 - y2) in dist:
            if not (((x1 - x2) == 1 and (y1 - y2) == -1) or ((x1 - x2) == -1 and (y1 - y2) == 1)) :
                TotalEdges.append([couple])
    return TotalEdges

# %%
TrajectoryWithAllEdges = TrajectoryAllEdges(TrajectoryPoints)

# %%
import numpy as np
import pylab as plt
from matplotlib import collections  as mc

fig, ax = plt.subplots()

for el in TrajectoryWithAllEdges:
    line = []
    line = mc.LineCollection(el, linewidths=0.3)
    ax.add_collection(line)
    ax.autoscale()
    ax.margins(0.1)

plt.grid()
plt.axis('equal')


plt.show()

# %% [markdown]
# Let's try graph libraries

# %%
import networkx as nx
G = nx.Graph()

# %%
def NotesToEdges(TrajectoryPoints, TrajectoryNoteEdges, Graph):
    listofPoints = []
    for i, dicts in enumerate(TrajectoryPoints):
        for el in dicts:
            Graph.add_node(dicts[el])
        for j in TrajectoryV1Edges[i]:
            Graph.add_edge(j[0], j[1])
    return Graph

# %%
newGraph = NotesToEdges(TrajectoryPoints, TrajectoryNoteEdges, G)
nx.draw(newGraph)
plt.show()

# %%
options = {
...     'node_color': 'red',
...     'node_size': 20,
...     'width': 1,
... }
nx.draw_circular(newGraph, **options)

# %% [markdown]
# Plotting with Delaunay Triangulations either computes a complete graph which is not hepful either it need more than three points to compute.

# %%
from scipy.spatial import Delaunay

def DelaunaySimplices(TrajectoryPoints):
    fig, ax = plt.subplots()
    plt.axis('equal')
    ax.grid(True) 
    for dicts in TrajectoryPoints:
        l = []
        for el in dicts:
            l.append(dicts[el])
        points = np.array(l)
        tri = Delaunay(points)
        plt.triplot(points[:,0], points[:,1], tri.simplices)
        plt.plot(points[:,0], points[:,1], 'o')
    plt.show()

# %%
DelaunaySimplices(TrajectoryPoints)

# %%
from matplotlib.animation import FuncAnimation
import numpy as np
# %matplotlib inline

def aniPlot(axeX, axesY, limitLow, limitHigh):
    fig, ax = plt.subplots()
#     ax.set_xticks(np.arange(limitLow, limitHigh, 1)) 
#     ax.set_yticks(np.arange(limitLow, limitHigh, 1))  
    ax.grid()
    xdata, ydata = [], []
    N = len(axeX)
    ln, = plt.plot([], [], '-o')

    def init():
        ax.set_xlim(limitLow, limitHigh)
        ax.set_ylim(limitLow, limitHigh)
        return ln,

    def update(frame):
        xdata.append(axeX[frame])
        ydata.append(axeY[frame])
        ln.set_data(xdata, ydata)
        return ln,

    ani = FuncAnimation(fig, update, frames=np.arange(N),
                        init_func=init, blit=True)

    plt.rc('animation', html='html5')
    return ani

    
aniPlot(axeX, axeY, -15, 10)

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.collections import LineCollection
import matplotlib.animation as animation

lines=[]
for i in range(10):
    for j in range(10):
        lines.append([(0, i), (1, j)])

        
    line = []
for el in TrajectoryWithAllEdges:
    line = mc.LineCollection(el, linewidths=0.3)
    ax.add_collection(line)
    ax.autoscale()
    ax.margins(0.1)

        
        
        
fig, ax = plt.subplots()
colors = np.random.random(len(lines))
col = LineCollection(lines, array=colors, cmap=plt.cm.gray)
ax.add_collection(col)
ax.autoscale()


ims=[]
plt.draw()
for i in range(100):
    col = LineCollection(lines,cmap=plt.cm.gray)
    colors = np.random.random(len(lines))
    col.set_array(colors)
    ax.draw_artist(col)
    im=ax.add_collection(col)
    ims.append([im])
ani = animation.ArtistAnimation(fig, ims, interval=25, blit=True,repeat_delay=10000)
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.collections import LineCollection
import matplotlib.animation as animation

lines=[]
for i in range(10):
    for j in range(10):
        lines.append([(0, i), (1, j)])

fig, ax = plt.subplots()
colors = np.random.random(len(lines))
col = LineCollection(lines, array=colors, cmap=plt.cm.gray)
ax.add_collection(col)
ax.autoscale()


ims=[]
for i in range(100):
    col = LineCollection(lines,cmap=plt.cm.gray)
    colors = np.random.random(len(lines))
    col.set_array(colors)
    im=ax.add_collection(col)
    ims.append([im])
ani = animation.ArtistAnimation(fig, ims, interval=25, blit=True,repeat_delay=10000)
plt.show()
