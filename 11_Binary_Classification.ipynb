# %% [markdown]
# # Binary Classification (Composer Based)

# %%
import csv # create csv
import pandas as pd # Open and manage CSV files
import pickle # Open python objects
import os # Directory Control
import seaborn # easy plots
from itertools import product
import warnings # find and don't show warnings

from structural_functions import mergeDicts

# %% [markdown]
# ### Lets load our Data

# %%
def loadDicts(directory):
    subDir = [x[0] for x in os.walk(directory)]
    graphList = []
    for i, subfolder in enumerate(subDir[1:]):
        graph = dict()
        for file in os.listdir(subfolder):
            if file.endswith(".p") :
                complete_name = subfolder + '/' + file
                print('Rendering --> ', file)
                graph.update(pickle.load(open(complete_name, "rb")))
        graphList.append(graph)
    return graphList

# %%
def write2csv(directory, file_name,  data):
    directory = directory + '/' + file_name + '.csv'
    with open(directory, 'w') as csvFile:
        writer = csv.writer(csvFile)
        writer.writerows(data)
    csvFile.close()

# %%
def createCSVfiles(graphList):
    for i, graphs1 in enumerate(graphList):
        if i!=7:
            for j, graphs2 in enumerate(graphList[i+1:]):
                graphs = mergeDicts(graphs1, graphs2)
                values = [['Composer', 'Kalz Centrality', 'Global Clustering', 'Square Clustering', 'Harmonic Centrality', 'Closeness Centrality', 'Tonnetz']]
                composer = ''
                for graph in graphs:
                    values.append([graph.composer, graph.kalz_coef, graph.glob_clust_coef, graph.square_clustering_coef, graph.harmonic_coef, graph.closeness_coef, graph.trajectory.Tonnetz])
                write2csv('Comparison_Results/binary_classification', str(i)+str(j+i+1), values)

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
from sklearn.preprocessing import LabelEncoder

def encodingData(data) :
    label_quality = LabelEncoder()
    data = label_quality.fit_transform(data)
    return label_quality, data

# %%
def dropingData(data, label2Drop):
    data = data.drop(columns=label2Drop)
    return data

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
    
def separateDataset(data, label):
    X = data.drop(label, axis=1)
    y = data[label]
    return X, y

def splitDataset(data, label):
    X, y = separateDataset(data, label)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, stratify=y)
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    return X_train, y_train, X_test, y_test

# %%
def savePrints(string2output):
    complete_directory = 'Comparison_Results/binary_classification/results.txt'
    file = open(complete_directory,"w")
    file.write(string2output)
    file.close()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

def applyRandomForest(data, label):
    X_train, y_train, X_test, y_test = splitDataset(data, label)
    rfc = RandomForestClassifier(n_estimators=1000, criterion="entropy")
    rfc.fit(X_train, y_train)
    pred_rfc = rfc.predict(X_test)

    return "%.2f" % round(f1_score(y_test, pred_rfc, average='weighted'), 2)

# %%
def BinaryPredictions(directory):
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        # Do stuff here
        
        print('\033[1m' + 'BINARY CLASSIFICATION \n\n')
        print('\033[0m' + '| Composers | Score | Notes |')
        print('| -----------------------------------| --------------- |----------------------------------------|')
        for file in os.listdir(directory):
            if file.endswith('.csv'):
                complete_name = directory + '/' + file
                data = pd.read_csv(complete_name, sep = ',')
                data['Tonnetz'] = encodingData(data['Tonnetz'])[1]
                label_quality, data['Composer'] = encodingData(data['Composer'])
                composers = label_quality.inverse_transform([0])[0] + ' vs ' + label_quality.inverse_transform([1])[0]
                score = applyRandomForest(data, 'Composer')
                notes = 'All Atributes'
                print('| ', composers , ' | ', score, ' | ', notes , ' | ')
                score = applyRandomForest(dropingData(data, 'Harmonic Centrality'), 'Composer')
                notes = 'Wihout Harmonic Centrality'
                print('| ', composers , ' | ', score, ' | ', notes , ' | ')
                score = applyRandomForest(dropingData(data, 'Closeness Centrality'), 'Composer')
                notes = 'Wihout Closeness Centrality'
                print('| ', composers , ' | ', score, ' | ', notes , ' | ')
                score = applyRandomForest(dropingData(data, 'Kalz Centrality'), 'Composer')
                notes = 'Wihout Kalz Centrality'
                print('| ', composers , ' | ', score, ' | ', notes , ' | ')
                score = applyRandomForest(dropingData(data, 'Global Clustering'), 'Composer')
                notes = 'Wihout Global Clustering'
                print('| ', composers , ' | ', score, ' | ', notes , ' | ')
                score = applyRandomForest(dropingData(data, 'Square Clustering'), 'Composer')
                notes = 'Wihout Square Clustering'
                print('| ', composers , ' | ', score, ' | ', notes , ' | ')
                score = applyRandomForest(dropingData(data, 'Tonnetz'), 'Composer')
                notes = 'Wihout Tonnetz'
                print('| ', composers , ' | ', score, ' | ', notes , ' | ')

# %%
BinaryPredictions('Comparison_Results/binary_classification')
# Out:
# BINARY CLASSIFICATION
#
#
# | Composers | Score | Notes |
# | -----------------------------------| --------------- |----------------------------------------|
# |  bach vs beethoven  |  0.98  |  All Atributes  |
# |  bach vs beethoven  |  1.00  |  Wihout Harmonic Centrality  |
# |  bach vs beethoven  |  0.98  |  Wihout Closeness Centrality  |
# |  bach vs beethoven  |  1.00  |  Wihout Kalz Centrality  |
# |  bach vs beethoven  |  0.98  |  Wihout Global Clustering  |
# |  bach vs beethoven  |  0.98  |  Wihout Square Clustering  |
# |  bach vs beethoven  |  1.00  |  Wihout Tonnetz  |
# |  bach vs beethoven  |  0.75  |  All Atributes  |
# |  bach vs beethoven  |  0.74  |  Wihout Harmonic Centrality  |
# |  bach vs beethoven  |  0.79  |  Wihout Closeness Centrality  |
# |  bach vs beethoven  |  0.82  |  Wihout Kalz Centrality  |
# |  bach vs beethoven  |  0.80  |  Wihout Global Clustering  |
# |  bach vs beethoven  |  0.76  |  Wihout Square Clustering  |
# |  bach vs beethoven  |  0.69  |  Wihout Tonnetz  |
# |  Unknown vs bach  |  0.83  |  All Atributes  |
# |  Unknown vs bach  |  0.83  |  Wihout Harmonic Centrality  |
# |  Unknown vs bach  |  0.83  |  Wihout Closeness Centrality  |
# |  Unknown vs bach  |  0.88  |  Wihout Kalz Centrality  |
# |  Unknown vs bach  |  0.80  |  Wihout Global Clustering  |
# |  Unknown vs bach  |  0.80  |  Wihout Square Clustering  |
# |  Unknown vs bach  |  0.90  |  Wihout Tonnetz  |
# |  bach vs beethoven  |  0.95  |  All Atributes  |
# |  bach vs beethoven  |  0.71  |  Wihout Harmonic Centrality  |
# |  bach vs beethoven  |  0.87  |  Wihout Closeness Centrality  |
# |  bach vs beethoven  |  0.82  |  Wihout Kalz Centrality  |
# |  bach vs beethoven  |  0.78  |  Wihout Global Clustering  |
# |  bach vs beethoven  |  0.88  |  Wihout Square Clustering  |
# |  bach vs beethoven  |  0.93  |  Wihout Tonnetz  |
# |  bach vs beethoven  |  0.69  |  All Atributes  |
# |  bach vs beethoven  |  0.74  |  Wihout Harmonic Centrality  |
# |  bach vs beethoven  |  0.71  |  Wihout Closeness Centrality  |
# |  bach vs beethoven  |  0.58  |  Wihout Kalz Centrality  |
# |  bach vs beethoven  |  0.66  |  Wihout Global Clustering  |
# |  bach vs beethoven  |  0.68  |  Wihout Square Clustering  |
# |  bach vs beethoven  |  0.74  |  Wihout Tonnetz  |
# |  bach vs beethoven  |  0.69  |  All Atributes  |
# |  bach vs beethoven  |  0.78  |  Wihout Harmonic Centrality  |
# |  bach vs beethoven  |  0.73  |  Wihout Closeness Centrality  |
# |  bach vs beethoven  |  0.72  |  Wihout Kalz Centrality  |
# |  bach vs beethoven  |  0.79  |  Wihout Global Clustering  |
# |  bach vs beethoven  |  0.74  |  Wihout Square Clustering  |
# |  bach vs beethoven  |  0.66  |  Wihout Tonnetz  |
# |  bach vs beethoven  |  0.67  |  All Atributes  |
# |  bach vs beethoven  |  0.73  |  Wihout Harmonic Centrality  |
# |  bach vs beethoven  |  0.68  |  Wihout Closeness Centrality  |
# |  bach vs beethoven  |  0.81  |  Wihout Kalz Centrality  |
# |  bach vs beethoven  |  0.69  |  Wihout Global Clustering  |
# |  bach vs beethoven  |  0.76  |  Wihout Square Clustering  |
# |  bach vs beethoven  |  0.77  |  Wihout Tonnetz  |
# |  beethoven vs chopin  |  0.76  |  All Atributes  |
# |  beethoven vs chopin  |  0.66  |  Wihout Harmonic Centrality  |
# |  beethoven vs chopin  |  0.76  |  Wihout Closeness Centrality  |
# |  beethoven vs chopin  |  0.73  |  Wihout Kalz Centrality  |
# |  beethoven vs chopin  |  0.66  |  Wihout Global Clustering  |
# |  beethoven vs chopin  |  0.79  |  Wihout Square Clustering  |
# |  beethoven vs chopin  |  0.88  |  Wihout Tonnetz  |
# |  Unknown vs beethoven  |  0.76  |  All Atributes  |
# |  Unknown vs beethoven  |  0.86  |  Wihout Harmonic Centrality  |
# |  Unknown vs beethoven  |  0.83  |  Wihout Closeness Centrality  |
# |  Unknown vs beethoven  |  0.83  |  Wihout Kalz Centrality  |
# |  Unknown vs beethoven  |  0.79  |  Wihout Global Clustering  |
# |  Unknown vs beethoven  |  0.81  |  Wihout Square Clustering  |
# |  Unknown vs beethoven  |  0.80  |  Wihout Tonnetz  |
# |  beethoven vs monteverdi  |  0.95  |  All Atributes  |
# |  beethoven vs monteverdi  |  1.00  |  Wihout Harmonic Centrality  |
# |  beethoven vs monteverdi  |  0.95  |  Wihout Closeness Centrality  |
# |  beethoven vs monteverdi  |  1.00  |  Wihout Kalz Centrality  |
# |  beethoven vs monteverdi  |  0.98  |  Wihout Global Clustering  |
# |  beethoven vs monteverdi  |  1.00  |  Wihout Square Clustering  |
# |  beethoven vs monteverdi  |  1.00  |  Wihout Tonnetz  |
# |  beethoven vs mozart  |  0.68  |  All Atributes  |
# |  beethoven vs mozart  |  0.47  |  Wihout Harmonic Centrality  |
# |  beethoven vs mozart  |  0.54  |  Wihout Closeness Centrality  |
# |  beethoven vs mozart  |  0.60  |  Wihout Kalz Centrality  |
# |  beethoven vs mozart  |  0.53  |  Wihout Global Clustering  |
# |  beethoven vs mozart  |  0.50  |  Wihout Square Clustering  |
# |  beethoven vs mozart  |  0.59  |  Wihout Tonnetz  |
# |  beethoven vs palestrina  |  0.98  |  All Atributes  |
# |  beethoven vs palestrina  |  0.98  |  Wihout Harmonic Centrality  |
# |  beethoven vs palestrina  |  0.95  |  Wihout Closeness Centrality  |
# |  beethoven vs palestrina  |  0.98  |  Wihout Kalz Centrality  |
# |  beethoven vs palestrina  |  0.98  |  Wihout Global Clustering  |
# |  beethoven vs palestrina  |  0.98  |  Wihout Square Clustering  |
# |  beethoven vs palestrina  |  0.98  |  Wihout Tonnetz  |
# |  beethoven vs schumann  |  0.82  |  All Atributes  |
# |  beethoven vs schumann  |  0.82  |  Wihout Harmonic Centrality  |
# |  beethoven vs schumann  |  0.84  |  Wihout Closeness Centrality  |
# |  beethoven vs schumann  |  0.78  |  Wihout Kalz Centrality  |
# |  beethoven vs schumann  |  0.80  |  Wihout Global Clustering  |
# |  beethoven vs schumann  |  0.78  |  Wihout Square Clustering  |
# |  beethoven vs schumann  |  0.71  |  Wihout Tonnetz  |
# |  Unknown vs chopin  |  0.86  |  All Atributes  |
# |  Unknown vs chopin  |  0.72  |  Wihout Harmonic Centrality  |
# |  Unknown vs chopin  |  0.83  |  Wihout Closeness Centrality  |
# |  Unknown vs chopin  |  0.78  |  Wihout Kalz Centrality  |
# |  Unknown vs chopin  |  0.80  |  Wihout Global Clustering  |
# |  Unknown vs chopin  |  0.81  |  Wihout Square Clustering  |
# |  Unknown vs chopin  |  0.75  |  Wihout Tonnetz  |
# |  chopin vs monteverdi  |  0.94  |  All Atributes  |
# |  chopin vs monteverdi  |  0.86  |  Wihout Harmonic Centrality  |
# |  chopin vs monteverdi  |  0.94  |  Wihout Closeness Centrality  |
# |  chopin vs monteverdi  |  0.89  |  Wihout Kalz Centrality  |
# |  chopin vs monteverdi  |  0.89  |  Wihout Global Clustering  |
# |  chopin vs monteverdi  |  0.92  |  Wihout Square Clustering  |
# |  chopin vs monteverdi  |  0.94  |  Wihout Tonnetz  |
# |  chopin vs mozart  |  0.68  |  All Atributes  |
# |  chopin vs mozart  |  0.73  |  Wihout Harmonic Centrality  |
# |  chopin vs mozart  |  0.79  |  Wihout Closeness Centrality  |
# |  chopin vs mozart  |  0.71  |  Wihout Kalz Centrality  |
# |  chopin vs mozart  |  0.71  |  Wihout Global Clustering  |
# |  chopin vs mozart  |  0.67  |  Wihout Square Clustering  |
# |  chopin vs mozart  |  0.67  |  Wihout Tonnetz  |
# |  chopin vs palestrina  |  0.89  |  All Atributes  |
# |  chopin vs palestrina  |  0.86  |  Wihout Harmonic Centrality  |
# |  chopin vs palestrina  |  0.86  |  Wihout Closeness Centrality  |
# |  chopin vs palestrina  |  0.86  |  Wihout Kalz Centrality  |
# |  chopin vs palestrina  |  0.86  |  Wihout Global Clustering  |
# |  chopin vs palestrina  |  0.89  |  Wihout Square Clustering  |
# |  chopin vs palestrina  |  0.86  |  Wihout Tonnetz  |
# |  chopin vs schumann  |  0.49  |  All Atributes  |
# |  chopin vs schumann  |  0.45  |  Wihout Harmonic Centrality  |
# |  chopin vs schumann  |  0.59  |  Wihout Closeness Centrality  |
# |  chopin vs schumann  |  0.67  |  Wihout Kalz Centrality  |
# |  chopin vs schumann  |  0.62  |  Wihout Global Clustering  |
# |  chopin vs schumann  |  0.56  |  Wihout Square Clustering  |
# |  chopin vs schumann  |  0.45  |  Wihout Tonnetz  |
# |  Unknown vs monteverdi  |  0.92  |  All Atributes  |
# |  Unknown vs monteverdi  |  0.97  |  Wihout Harmonic Centrality  |
# |  Unknown vs monteverdi  |  1.00  |  Wihout Closeness Centrality  |
# |  Unknown vs monteverdi  |  0.97  |  Wihout Kalz Centrality  |
# |  Unknown vs monteverdi  |  0.97  |  Wihout Global Clustering  |
# |  Unknown vs monteverdi  |  1.00  |  Wihout Square Clustering  |
# |  Unknown vs monteverdi  |  0.94  |  Wihout Tonnetz  |
# |  Unknown vs mozart  |  0.70  |  All Atributes  |
# |  Unknown vs mozart  |  0.73  |  Wihout Harmonic Centrality  |
# |  Unknown vs mozart  |  0.88  |  Wihout Closeness Centrality  |
# |  Unknown vs mozart  |  0.82  |  Wihout Kalz Centrality  |
# |  Unknown vs mozart  |  0.63  |  Wihout Global Clustering  |
# |  Unknown vs mozart  |  0.82  |  Wihout Square Clustering  |
# |  Unknown vs mozart  |  0.88  |  Wihout Tonnetz  |
# |  Unknown vs palestrina  |  0.92  |  All Atributes  |
# |  Unknown vs palestrina  |  0.94  |  Wihout Harmonic Centrality  |
# |  Unknown vs palestrina  |  1.00  |  Wihout Closeness Centrality  |
# |  Unknown vs palestrina  |  0.94  |  Wihout Kalz Centrality  |
# |  Unknown vs palestrina  |  0.97  |  Wihout Global Clustering  |
# |  Unknown vs palestrina  |  0.94  |  Wihout Square Clustering  |
# |  Unknown vs palestrina  |  1.00  |  Wihout Tonnetz  |
# |  Unknown vs schumann  |  0.82  |  All Atributes  |
# |  Unknown vs schumann  |  0.87  |  Wihout Harmonic Centrality  |
# |  Unknown vs schumann  |  0.85  |  Wihout Closeness Centrality  |
# |  Unknown vs schumann  |  0.74  |  Wihout Kalz Centrality  |
# |  Unknown vs schumann  |  0.79  |  Wihout Global Clustering  |
# |  Unknown vs schumann  |  0.82  |  Wihout Square Clustering  |
# |  Unknown vs schumann  |  0.80  |  Wihout Tonnetz  |
# |  monteverdi vs mozart  |  0.91  |  All Atributes  |
# |  monteverdi vs mozart  |  0.97  |  Wihout Harmonic Centrality  |
# |  monteverdi vs mozart  |  0.97  |  Wihout Closeness Centrality  |
# |  monteverdi vs mozart  |  0.91  |  Wihout Kalz Centrality  |
# |  monteverdi vs mozart  |  0.88  |  Wihout Global Clustering  |
# |  monteverdi vs mozart  |  0.88  |  Wihout Square Clustering  |
# |  monteverdi vs mozart  |  0.94  |  Wihout Tonnetz  |
# |  monteverdi vs palestrina  |  0.86  |  All Atributes  |
# |  monteverdi vs palestrina  |  0.81  |  Wihout Harmonic Centrality  |
# |  monteverdi vs palestrina  |  0.78  |  Wihout Closeness Centrality  |
# |  monteverdi vs palestrina  |  0.80  |  Wihout Kalz Centrality  |
# |  monteverdi vs palestrina  |  0.86  |  Wihout Global Clustering  |
# |  monteverdi vs palestrina  |  0.72  |  Wihout Square Clustering  |
# |  monteverdi vs palestrina  |  0.75  |  Wihout Tonnetz  |
# |  monteverdi vs schumann  |  0.90  |  All Atributes  |
# |  monteverdi vs schumann  |  0.80  |  Wihout Harmonic Centrality  |
# |  monteverdi vs schumann  |  0.97  |  Wihout Closeness Centrality  |
# |  monteverdi vs schumann  |  0.95  |  Wihout Kalz Centrality  |
# |  monteverdi vs schumann  |  0.85  |  Wihout Global Clustering  |
# |  monteverdi vs schumann  |  0.90  |  Wihout Square Clustering  |
# |  monteverdi vs schumann  |  0.92  |  Wihout Tonnetz  |
# |  mozart vs palestrina  |  1.00  |  All Atributes  |
# |  mozart vs palestrina  |  0.85  |  Wihout Harmonic Centrality  |
# |  mozart vs palestrina  |  0.91  |  Wihout Closeness Centrality  |
# |  mozart vs palestrina  |  0.97  |  Wihout Kalz Centrality  |
# |  mozart vs palestrina  |  0.91  |  Wihout Global Clustering  |
# |  mozart vs palestrina  |  1.00  |  Wihout Square Clustering  |
# |  mozart vs palestrina  |  0.91  |  Wihout Tonnetz  |
# |  mozart vs schumann  |  0.68  |  All Atributes  |
# |  mozart vs schumann  |  0.54  |  Wihout Harmonic Centrality  |
# |  mozart vs schumann  |  0.65  |  Wihout Closeness Centrality  |
# |  mozart vs schumann  |  0.76  |  Wihout Kalz Centrality  |
# |  mozart vs schumann  |  0.57  |  Wihout Global Clustering  |
# |  mozart vs schumann  |  0.52  |  Wihout Square Clustering  |
# |  mozart vs schumann  |  0.59  |  Wihout Tonnetz  |
# |  palestrina vs schumann  |  0.85  |  All Atributes  |
# |  palestrina vs schumann  |  0.87  |  Wihout Harmonic Centrality  |
# |  palestrina vs schumann  |  0.87  |  Wihout Closeness Centrality  |
# |  palestrina vs schumann  |  0.82  |  Wihout Kalz Centrality  |
# |  palestrina vs schumann  |  0.90  |  Wihout Global Clustering  |
# |  palestrina vs schumann  |  0.80  |  Wihout Square Clustering  |
# |  palestrina vs schumann  |  0.90  |  Wihout Tonnetz  |
